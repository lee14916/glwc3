# %%
# %load_ext autoreload
# %autoreload 2

import util as yu
from util import *
import util_moments as yum

yu.setpath('doSVD')

projs=['P0', 'Px', 'Py', 'Pz']
inserts=['tt', 'tx', 'ty', 'tz', 'xx', 'xy', 'xz', 'yy', 'yz', 'zz']
enss=['b','c','d']

# %%
max_mom2_pc,max_mom2_pf=25,0 # conn

n2qpp1s=yum.get_n2qpp1s(max_mom2_pc,max_mom2_pf,noZeroQ=True)
txts=[f'{ens}_{yu.n2qpp12str(n2qpp1)}' for ens in enss for n2qpp1 in n2qpp1s]
yu.save_txt('data_aux/ens_n2qpp1_run',txts)
