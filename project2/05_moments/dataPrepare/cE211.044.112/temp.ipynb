# %%
import os
import shutil

path='data_aux/cfgs_run'
with open(path,'r') as f:
    cfgs=f.read().splitlines()
    
# path='/p/project1/ngff/li47/code/scratch/run/05_moments_run5_1DV/cE211.044.112/data_avgmore/'
# t=os.listdir(path)
# print(len(t))
# for cfg in t:
#     if cfg in cfgs:
#         continue
#     p=f'{path}{cfg}'
#     print(cfg,os.listdir(p))
#     shutil.rmtree(p)
# Out:
# 460
