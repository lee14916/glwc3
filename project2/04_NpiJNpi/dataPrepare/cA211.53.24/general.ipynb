# %%
import numpy as np
import h5py

path1='/capstor/store/cscs/userlab/s1174/lyan/code/scratch/run/04_NpiJNpi/cA211.53.24/run/a0000/V2.h5'
path2='/capstor/store/cscs/userlab/s1174/lyan/code/scratch/run/04_NpiJNpi/cA211.53.24/fromCyclon/threept0000_V2NEW0_0.h5'
with h5py.File(path1) as f1, h5py.File(path2) as f2:
    src='sx00sy00sz00st00'
    print(f1[src]['V24']['V2'])
    t1=f1[src]['V24']['V2'][:,3,0]
    print(f2[src]['group_v2']['dataset_v2'].shape)
    t2=f2[src]['group_v2']['dataset_v2'][:,0,0]
    print(t1.shape,t2.shape)
    dt=t1-t2
    print(t1[:,0,0,0,0,0])
    print(t2[:,0,0,0,0,0])
    print(dt[10,0,0,0,0,0])
# Out:
# <HDF5 dataset "V2": shape (48, 7, 1, 4, 4, 4, 3, 2), type "<f4">
# (48, 1, 1, 4, 4, 4, 3, 2)
# (48, 4, 4, 4, 3, 2) (48, 4, 4, 4, 3, 2)
# [ 6.56636928e-07 -7.08256209e-07 -1.35138407e-08  6.13898479e-08
#  -1.75586052e-08  2.72615125e-07 -1.17683996e-07  6.24122620e-09
#   2.64487703e-08  1.22471304e-08 -6.07029165e-08 -3.19366471e-08
#  -1.04592075e-07 -2.94476941e-08  3.40367095e-08 -1.49216159e-08
#   9.39617628e-09  2.88610060e-08 -1.08568310e-08 -6.29437658e-09
#   1.08084155e-08  7.13104464e-09  1.48596300e-08 -4.67877825e-09
#   5.18274479e-10 -5.28111688e-09  2.76959855e-09 -8.60998561e-09
#  -7.26049887e-10  4.13424583e-09 -1.13974368e-08 -4.21437285e-09
#  -6.12222539e-09 -4.87838658e-09 -1.58179976e-08  2.21844942e-09
#  -9.12100340e-10  3.51115714e-09  1.76886807e-08 -2.08969775e-09
#  -3.29612648e-09  8.72539019e-08  7.11092341e-08 -1.01610276e-10
#  -1.71137060e-07  1.91036264e-07  1.91891630e-07 -1.55025447e-07]
# ...

# %%
import numpy as np
import h5py

path1='/capstor/store/cscs/userlab/s1174/lyan/code/scratch/run/04_NpiJNpi/cA211.53.24/run/a0000/propUSS_check.h5'
path2='/capstor/store/cscs/userlab/s1174/lyan/code/scratch/run/04_NpiJNpi/cA211.53.24/fromCyclon/propUP_SS_0_0000.h5'
with h5py.File(path1) as f1, h5py.File(path2) as f2:
    t1=f1['data'][0,0,0,0,:,0,0,0,0]
    t2=f2['data'][0,0,0,0,:,0,0,0,0]
    print(t1)
    print(t2)
    print(t1-t2)
# Out:
# [ 3.9271737e-05  2.3582983e-05 -5.5635628e-05  1.8403989e-05
#   3.4733584e-06 -4.3282245e-05  1.7631007e-06 -1.4249427e-05
#  -9.5128662e-06 -6.1420992e-06  1.5866754e-05  4.1476872e-07
#  -1.3422858e-05 -8.3476098e-06  5.6310705e-06  1.2672579e-05
#  -5.2959585e-06 -7.2423850e-06 -1.4974780e-06  2.3454842e-07
#   2.8985964e-06 -2.4204069e-06 -1.7382739e-06 -2.6993130e-06
#   2.1599726e-08 -2.5674956e-06  9.2665607e-07  6.5983062e-07
#   2.9653843e-06 -1.8568616e-07 -4.0693426e-06 -1.3800656e-06
#   1.9973616e-06  1.8875039e-06  3.5456230e-06  2.6146907e-07
#   1.2490297e-06 -4.5594288e-06  7.9535249e-07 -2.2765662e-06
#  -2.6647001e-06  1.4467445e-06 -7.8428620e-06  4.1270296e-06
#  -2.5741317e-06 -4.8474108e-06  2.7652575e-05  1.9698940e-05]
# [ 5.08313897e-05  4.08200049e-06 -3.44091313e-05  1.20336426e-05
#   7.98048040e-06 -5.11373473e-05  2.07995563e-05  1.29018772e-05
#  -3.96556317e-08 -1.85575664e-05  1.10416795e-05  3.74683935e-07
# ...
