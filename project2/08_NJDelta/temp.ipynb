# %%
# %load_ext autoreload
# %autoreload 2

import util as yu
from util import *

# %%
path1='/capstor/store/cscs/userlab/lp139/lyan/code/scratch/run/testYan/run/a0000_aftertunning/Diagram_N_0000_sx38sy35sz44st000.h5'
path2='/capstor/store/cscs/userlab/lp139/lyan/code/scratch/run/testYan/fromFerenc/Diagram0000_sx38sy35sz44st000_N.h5'

with h5py.File(path1) as f1, h5py.File(path2) as f2:
    group='sx38sy35sz44st00'; dataset='NP'
    print(f1[group].keys())
    print(f1[f'{group}/{dataset}'][10,0,0,0,0])
    print(f2[f'{group}/{dataset}'][10,0,0,0,0])
# Out:
# <KeysViewHDF5 ['N0', 'NP', 'mvec']>
# 1.605237e-11
# 1.6052364e-11

# %%
# path1='/capstor/store/cscs/userlab/lp139/lyan/code/scratch/run/testYan/run/a0000_aftertunning/propUSS.h5'
path1='/capstor/store/cscs/userlab/lp139/lyan/code/scratch/run/testYan/fromFerenc/propUP_rotated.h5'
path2='/capstor/store/cscs/userlab/lp139/lyan/code/scratch/run/testYan/fromFerenc/propUPSS_FERENC.h5'

# path2='/capstor/store/cscs/userlab/lp139/lyan/code/scratch/run/testYan/run/a0000_backup/propUSS.h5'

with h5py.File(path1) as f1, h5py.File(path2) as f2:
    group=''; dataset='data'
    # print(f1.keys())
    # print(f1[group].keys())
    print(f1[f'{group}/{dataset}'][0,0,0,0, 0,0,2,1, 0])
    print(f2[f'{group}/{dataset}'][0,0,0,0, 0,0,2,1, 0])
# Out:
# 7.673845e-06
# -2.5597215e-06
