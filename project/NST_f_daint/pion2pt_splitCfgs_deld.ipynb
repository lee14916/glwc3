# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,warnings
import h5py, pandas
import numpy as np
np.seterr(invalid=['ignore','warn'][0])
import math,cmath,pickle
from matplotlib.backends.backend_pdf import PdfPages
from scipy.optimize import curve_fit,fsolve
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('default')
mpl.rcParams['figure.facecolor'] = 'white'
mpl.rcParams['figure.titlesize'] = 20
mpl.rcParams['figure.figsize'] = [6.4*1.2,4.8*1.2]
mpl.rcParams['axes.labelsize'] = 30
mpl.rcParams['axes.titlesize'] = 30
mpl.rcParams['lines.marker'] = 's'
mpl.rcParams['lines.linestyle'] = ''
mpl.rcParams['lines.markersize'] = 5
mpl.rcParams['errorbar.capsize'] = 12
mpl.rcParams['xtick.labelsize'] = mpl.rcParams['ytick.labelsize'] = 22
mpl.rcParams['xtick.major.size'] = mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['xtick.top']=mpl.rcParams['ytick.right']=True
mpl.rcParams['xtick.direction']=mpl.rcParams['ytick.direction']='in'
mpl.rcParams['legend.fontsize'] = 24
plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

import puwr

# mpl.rcParams.update({"axes.grid" : True})
import util as yu
yu.flag_fast=False

def fsolve2(func,x0):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        res=fsolve(func, x0)[0]
    return res if res!=x0 else np.NaN

# %%
# path='/project/s1174/lyan/code/projectData/NST_e-scattering/pion2pt_more/cA2.09.48.h5'
# with h5py.File(path) as f:
#     imom=0
#     c2pt_piC_dat=f['data/piC'][:,:,imom]
#     c2pt_pi0_dat=np.complex128(f['data/pi0_conn'][:,:,imom]+f['data/pi0_disc'][:,:,imom])
#     vev_dat=np.complex128(f['data/vev'][:])
#     if True:
#         func=lambda t:(t+np.roll(np.flip(t,axis=1),1,axis=1))/2
#         c2pt_piC_dat=func(c2pt_piC_dat)
#         c2pt_pi0_dat=func(c2pt_pi0_dat)

path='/project/s1174/lyan/code/projectData/NST_f/cA2.09.48/data_merge/NST_f_meson2pt.h5'
with h5py.File(path) as f:
    imom=0
    c2pt_piC_dat=f['diags/P/data/pi+_pi+'][:,:,imom]
    c2pt_pi0_dat=f['diags/P/data/pi0_pi0'][:,:,imom]+f['diags/pi0f-pi0i/data/pi0_pi0'][:,:,imom]
    vev_dat=f['VEV/pi0f/data/pi0'][:]
    if True:
        func=lambda t:(t+np.roll(np.flip(t,axis=1),1,axis=1))/2
        c2pt_piC_dat=func(c2pt_piC_dat)
        c2pt_pi0_dat=func(c2pt_pi0_dat)

enss=['a']
# enss=['a','b']
ens2full={'a24':'cA211.53.24','a':'cA2.09.48','b':'B64','c':'C80','d':'D96'}
ens2label={'a24':'A24','a':'A48','b':'B64','c':'C80','d':'D96'}
ens2a={'a24':0.0908,'a':0.0938,'b':0.07957,'c':0.06821,'d':0.05692} # fm
ens2N={'a24':24,'a':48,'b':64,'c':80,'d':96}
ens2N_T={'a24':24*2,'a':48*2,'b':64*2,'c':80*2,'d':96*2}

hbarc = 1/197.3
ens2aInv={ens:1/(ens2a[ens]*hbarc) for ens in enss} # MeV

# %%
# 2pt

ens='a'
tfunc_C=lambda m,t:np.exp(-m*t)+np.exp(-m*(ens2N_T[ens]-t))
tau=1
def C2pt2meff(C2pt):
    return C2pt
    t=C2pt # dim=time
    t=(np.roll(t,-tau,axis=0))/(t)
    t=np.array([fsolve2(lambda m:((tfunc_C(m,xt+tau))/(tfunc_C(m,xt)))-ele, 0.0593) for xt,ele in enumerate(t)])
    return t

ds=[1,2,4,8,16,32]
ds=[4,8,16]
# ds=[]
Nsplit=12
Ntot=len(c2pt_piC_dat)
Nsize=Ntot//Nsplit
cfgss=[(0,Ntot),(Nsize,Ntot)]+[(i*Nsize,(i+1)*Nsize) for i in range(Nsplit)]

fig, axs = yu.getFigAxs(len(ds),len(cfgss),scale=1,sharex=True,sharey=True)
axs[0,0].set_ylim([0,2*1e5])
yu.addRowHeader(axs,[f'd={d}' for d in ds],fontsize=30)
yu.addColHeader(axs,[f'N={cfgs[1]-cfgs[0]}: from {cfgs[0]} to {cfgs[1]}' for cfgs in cfgss],fontsize=30)
xunit=ens2a[ens]; yunit=ens2aInv[ens]

mdtdssC=[]; mdtdss0=[]
for i_cfgs,cfgs in enumerate(cfgss):
    imin_cfg,imax_cfg=cfgs
    print('uwerr',cfgs,end='              \r')
    ax=axs[0,i_cfgs]
    
    for i_d,d in enumerate(ds):
        print(d,cfgs,end='              \r')
        ax=axs[i_d,i_cfgs]
        
        # c2pt_piC_jk=yu.jackknife(np.real(c2pt_piC_dat[imin_cfg:imax_cfg]),d=d)        
        # meff_jk=yu.jackmap(C2pt2meff,c2pt_piC_jk)
        # tmean,terr=yu.jackme(meff_jk)
        # plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
        # ax.errorbar(plt_x,plt_y,plt_yerr,color='r')
        
        c2pt_pi0_jk=yu.jackknife(np.real(c2pt_pi0_dat[imin_cfg:imax_cfg]),d=d)
        vev_jk=yu.jackknife(np.real(vev_dat[imin_cfg:imax_cfg]),d=d)
        c2pt_pi0_jk= c2pt_pi0_jk - vev_jk[:,None]**2
        meff_jk=yu.jackmap(C2pt2meff,c2pt_pi0_jk)
        tmean,terr=yu.jackme(meff_jk)
        plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
        ax.errorbar(plt_x,plt_y,plt_yerr,color='b')
        

plt.tight_layout()
plt.savefig(f'fig/pion2pt_splitCfgs_deld_c2pt.pdf')
plt.close()
# Out:
# 16 (1122, 1224)

# %%
# meff

ens='a'
tfunc_C=lambda m,t:np.exp(-m*t)+np.exp(-m*(ens2N_T[ens]-t))
tau=1
def C2pt2meff(C2pt):
    t=C2pt # dim=time
    t=(np.roll(t,-tau,axis=0))/(t)
    t=np.array([fsolve2(lambda m:((tfunc_C(m,xt+tau))/(tfunc_C(m,xt)))-ele, 0.0593) for xt,ele in enumerate(t)])
    return t

ds=[1,2,4,8,16,32]
ds=[4,8,16]
# ds=[]
Nsplit=12
Ntot=len(c2pt_piC_dat)
Nsize=Ntot//Nsplit
cfgss=[(0,Ntot),(Nsize,Ntot)]+[(i*Nsize,(i+1)*Nsize) for i in range(Nsplit)]

fig, axs = yu.getFigAxs(len(ds),len(cfgss),scale=1,sharex=True,sharey=True)
axs[0,0].set_ylim([0,300])
yu.addRowHeader(axs,[f'd={d}' for d in ds],fontsize=30)
yu.addColHeader(axs,[f'N={cfgs[1]-cfgs[0]}: from {cfgs[0]} to {cfgs[1]-1}' for cfgs in cfgss],fontsize=30)
xunit=ens2a[ens]; yunit=ens2aInv[ens]

mdtdssC=[]; mdtdss0=[]
for i_cfgs,cfgs in enumerate(cfgss):
    imin_cfg,imax_cfg=cfgs
    # print('uwerr',cfgs,end='              \r')
    ax=axs[0,i_cfgs]
    
    for i_d,d in enumerate(ds):
        print(d,cfgs,end='              \r')
        ax=axs[i_d,i_cfgs]
        
        c2pt_piC_jk=yu.jackknife(np.real(c2pt_piC_dat[imin_cfg:imax_cfg]),d=d)        
        meff_jk=yu.jackmap(C2pt2meff,c2pt_piC_jk)
        tmean,terr=yu.jackme(meff_jk)
        plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
        ax.errorbar(plt_x,plt_y,plt_yerr,color='r')
        
        c2pt_pi0_jk=yu.jackknife(np.real(c2pt_pi0_dat[imin_cfg:imax_cfg]),d=d)
        vev_jk=yu.jackknife(np.real(vev_dat[imin_cfg:imax_cfg]),d=d)
        c2pt_pi0_jk= c2pt_pi0_jk - vev_jk[:,None]**2
        meff_jk=yu.jackmap(C2pt2meff,c2pt_pi0_jk)
        tmean,terr=yu.jackme(meff_jk)
        plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
        ax.errorbar(plt_x,plt_y,plt_yerr,color='b')
        

plt.tight_layout()
plt.savefig(f'fig/pion2pt_splitCfgs_deld.pdf')
plt.close()
# Out:
# 16 (1122, 1224)

# %%
'''
uwerr may not work for pi0, since the vev subtraction involve correlation cancelling at non-interacting level?

'''


ens='a'
tfunc_C=lambda m,t:np.exp(-m*t)+np.exp(-m*(ens2N_T[ens]-t))
tau=1
def C2pt2meff(C2pt):
    t=C2pt # dim=time
    t=(np.roll(t,-tau,axis=0))/(t)
    t=np.array([fsolve2(lambda m:((tfunc_C(m,xt+tau))/(tfunc_C(m,xt)))-ele, 0.0593) for xt,ele in enumerate(t)])
    return t

ds=[1,2,4,8,16,32]
ds=[1,4,16]
# ds=[]
Nsplit=8
Nsize=len(c2pt_piC_dat)//Nsplit
cfgss=[(i*Nsize,(i+1)*Nsize) for i in range(Nsplit)]

fig, axs = yu.getFigAxs(len(ds)+1,len(cfgss),scale=1,sharex=True,sharey=True)
axs[0,0].set_ylim([0,300])
yu.addRowHeader(axs,['uwerr']+[f'd={d}' for d in ds],fontsize=30)
yu.addColHeader(axs,[f'N={cfgs[1]-cfgs[0]}: from {cfgs[0]} to {cfgs[1]}' for cfgs in cfgss],fontsize=30)
xunit=ens2a[ens]; yunit=ens2aInv[ens]

mdtdssC=[]; mdtdss0=[]
for i_cfgs,cfgs in enumerate(cfgss):
    imin_cfg,imax_cfg=cfgs
    print('uwerr',cfgs,end='              \r')
    ax=axs[0,i_cfgs]
    
    # data_uwerr=np.transpose(np.real(c2pt_piC_dat)[imin_cfg:imax_cfg,:,None],[1,2,0])
    # mdtds=[]
    # for time in range(ens2N_T[ens]):
    #     def func_uwerr(*pars):
    #         c2pt=pars
    #         res=fsolve2(lambda m:((tfunc_C(m,time+tau))/(tfunc_C(m,time)))-c2pt[(time+tau)%ens2N_T[ens]]/c2pt[time], 0.0593)
    #         # print(res*yunit)
    #         return res
    #     mean, delta, tint, d_tint = puwr.tauint(data_uwerr,func_uwerr)
    #     mdtds.append([mean,delta,tint,d_tint])
    # mdtds=np.array(mdtds)
    # mdtdssC.append(mdtds)
    # tmean=mdtds[:,0]; terr=mdtds[:,1]
    # plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
    # ax.errorbar(plt_x,plt_y,plt_yerr,color='r')
    
    data_uwerr=np.transpose(np.real(c2pt_pi0_dat)[imin_cfg:imax_cfg,:,None],[1,2,0])
    data_uwerr2=np.transpose(np.real(vev_dat)[imin_cfg:imax_cfg,None,None],[1,2,0])
    data_uwerr=np.concatenate([data_uwerr,data_uwerr2])
    mdtds=[]
    # for time in range(ens2N_T[ens]):
    for time in [10]:
        def func_uwerr(*pars):
            c2pt=pars[:-1]; vev=pars[-1]
            c2pt= c2pt - vev**2
            res=fsolve2(lambda m:((tfunc_C(m,time+tau))/(tfunc_C(m,time)))-c2pt[(time+tau)%ens2N_T[ens]]/c2pt[time], 0.0593)
            print(res*yunit)
            return res
        mean, delta, tint, d_tint = puwr.tauint(data_uwerr,func_uwerr)
        print(mean*yunit,delta*yunit)
        mdtds.append([mean,delta,tint,d_tint])
    mdtds=np.array(mdtds)
    mdtdss0.append(mdtds)
    tmean=mdtds[:,0]; terr=mdtds[:,1]
    plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
    ax.errorbar(plt_x,plt_y,plt_yerr,color='r')
    
    # for i_d,d in enumerate(ds):
    #     print(d,cfgs,end='              \r')
    #     ax=axs[i_d+1,i_cfgs]
        
    #     c2pt_piC_jk=yu.jackknife(np.real(c2pt_piC_dat[imin_cfg:imax_cfg]),d=d)        
    #     meff_jk=yu.jackmap(C2pt2meff,c2pt_piC_jk)
    #     tmean,terr=yu.jackme(meff_jk)
    #     plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
    #     ax.errorbar(plt_x,plt_y,plt_yerr,color='r')
        
    #     c2pt_pi0_jk=yu.jackknife(np.real(c2pt_pi0_dat[imin_cfg:imax_cfg]),d=d)
    #     vev_jk=yu.jackknife(np.real(vev_dat[imin_cfg:imax_cfg]),d=d)
    #     c2pt_pi0_jk= c2pt_pi0_jk - vev_jk[:,None]**2
    #     meff_jk=yu.jackmap(C2pt2meff,c2pt_pi0_jk)
    #     tmean,terr=yu.jackme(meff_jk)
    #     plt_x=range(len(tmean)); plt_y=tmean*yunit; plt_yerr=terr*yunit
    #     ax.errorbar(plt_x,plt_y,plt_yerr,color='b')
        

plt.tight_layout()
plt.savefig(f'fig/pion2pt_splitCfgs_deld.pdf')
plt.close()
